# %% [markdown]
# ## Clean CBS gpkg data
# - exclude cells (rows) with more than # NULL values
# - exclude cells (rows) with -99997.0 and -99995.0 values
# - exclude irrelevant attributes (columns)
# - compare with "../data/cbs/original/HH_500m_grid_2023.csv"

# %%
# import pacakages
import pandas as pd
import geopandas as gpd
import numpy as np
import shapely
import folium
from pathlib import Path

# %%
# load original CBS gpkg
cbs_full = gpd.read_file("../data/cbs/original/cbs_vk500_2023_v1.gpkg")

# %%
# check the basics
# shape
print(f"Shape of CBS gpkg: {cbs_full.shape[0]} x {cbs_full.shape[1]}\n")
# columns
print(f"Columns of CBS gpkg: {cbs_full.columns.tolist()}\n")
# check the first few rows
## print(f"First few rows of CBS gpkg: {cbs_full.head(10)}\n")
# check the datatypes
print(f"Datatypes of CBS gpkg: {cbs_full.dtypes}\n")
# check the null values
print (f"Null values of CBS gpkg: {cbs_full.isnull().sum()}\n")
# check the -999..0 values
print (f"Negative (null) values of CBS gpkg: {cbs_full[cbs_full == -99997.0].count()}\n")

# calculate the number of null values and -99997.0 values for each column
null_counts_per_col = cbs_full.isnull().sum()
neg99997_counts_per_col = (cbs_full == -99997.0).sum()
total_counts_per_col = null_counts_per_col + neg99997_counts_per_col

# print the results for each column
for col in cbs_full.columns:
    print(f"Column '{col}':  total = {total_counts_per_col[col]}")
# Out:
# Shape of CBS gpkg: 151108 x 137
#
# Columns of CBS gpkg: ['crs28992res500m', 'aantal_inwoners', 'aantal_mannen', 'aantal_vrouwen', 'aantal_inwoners_0_tot_15_jaar', 'aantal_inwoners_15_tot_25_jaar', 'aantal_inwoners_25_tot_45_jaar', 'aantal_inwoners_45_tot_65_jaar', 'aantal_inwoners_65_jaar_en_ouder', 'aantal_geboorten', 'percentage_geb_nederland_herkomst_nederland', 'percentage_geb_nederland_herkomst_overig_europa', 'percentage_geb_nederland_herkomst_buiten_europa', 'percentage_geb_buiten_nederland_herkomst_europa', 'percentage_geb_buiten_nederland_herkmst_buiten_europa', 'aantal_part_huishoudens', 'aantal_eenpersoonshuishoudens', 'aantal_meerpersoonshuishoudens_zonder_kind', 'aantal_eenouderhuishoudens', 'aantal_tweeouderhuishoudens', 'gemiddelde_huishoudensgrootte', 'aantal_woningen', 'aantal_woningen_bouwjaar_voor_1945', 'aantal_woningen_bouwjaar_45_tot_65', 'aantal_woningen_bouwjaar_65_tot_75', 'aantal_woningen_bouwjaar_75_tot_85', 'aantal_woningen_bouwjaar_85_tot_95', 'aantal_woningen_bouwjaar_95_tot_05', 'aantal_woningen_bouwjaar_05_tot_15', 'aantal_woningen_bouwjaar_15_en_later', 'aantal_meergezins_woningen', 'percentage_koopwoningen', 'percentage_huurwoningen', 'aantal_huurwoningen_in_bezit_woningcorporaties', 'aantal_niet_bewoonde_woningen', 'gemiddelde_woz_waarde_woning', 'gemiddeld_gasverbruik_woning', 'gemiddeld_elektriciteitsverbruik_woning', 'gemiddeld_inkomen_huishouden', 'percentage_laag_inkomen_huishouden', 'percentage_hoog_inkomen_huishouden', 'aantal_personen_met_uitkering_onder_aowlft', 'dichtstbijzijnde_grote_supermarkt_afstand_in_km', 'grote_supermarkt_aantal_binnen_1_km', 'grote_supermarkt_aantal_binnen_3_km', 'grote_supermarkt_aantal_binnen_5_km', 'dichtstbijzijnde_winkels_ov_dagel_levensm_afst_in_km', 'winkels_ov_dagel_levensm_aantal_binnen_1_km', 'winkels_ov_dagel_levensm_aantal_binnen_3_km', 'winkels_ov_dagel_levensm_aantal_binnen_5_km', 'dichtstbijzijnde_warenhuis_afstand_in_km', 'warenhuis_aantal_binnen_5_km', 'warenhuis_aantal_binnen_10_km', 'warenhuis_aantal_binnen_20_km', 'dichtstbijzijnde_cafe_afstand_in_km', 'cafe_aantal_binnen_1_km', 'cafe_aantal_binnen_3_km', 'cafe_aantal_binnen_5_km', 'dichtstbijzijnde_cafetaria_afstand_in_km', 'cafetaria_aantal_binnen_1_km', 'cafetaria_aantal_binnen_3_km', 'cafetaria_aantal_binnen_5_km', 'dichtstbijzijnde_hotel_afstand_in_km', 'hotel_aantal_binnen_5_km', 'hotel_aantal_binnen_10_km', 'hotel_aantal_binnen_20_km', 'dichtstbijzijnde_restaurant_afstand_in_km', 'restaurant_aantal_binnen_1_km', 'restaurant_aantal_binnen_3_km', 'restaurant_aantal_binnen_5_km', 'dichtstbijzijnde_buitenschoolse_opvang_afstand_in_km', 'buitenschoolse_opvang_aantal_binnen_1_km', 'buitenschoolse_opvang_aantal_binnen_3_km', 'buitenschoolse_opvang_aantal_binnen_5_km', 'dichtstbijzijnde_kinderdagverblijf_afstand_in_km', 'kinderdagverblijf_aantal_binnen_1_km', 'kinderdagverblijf_aantal_binnen_3_km', 'kinderdagverblijf_aantal_binnen_5_km', 'dichtstbijzijnde_brandweerkazerne_afstand_in_km', 'dichtstbijzijnde_oprit_hoofdverkeersweg_afstand_in_km', 'dichtstbijzijnde_overstapstation_afstand_in_km', 'dichtstbijzijnde_treinstation_afstand_in_km', 'dichtstbijzijnde_attractiepark_afstand_in_km', 'attractiepark_aantal_binnen_10_km', 'attractiepark_aantal_binnen_20_km', 'attractiepark_aantal_binnen_50_km', 'dichtstbijzijnde_bioscoop_afstand_in_km', 'bioscoop_aantal_binnen_5_km', 'bioscoop_aantal_binnen_10_km', 'bioscoop_aantal_binnen_20_km', 'dichtstbijzijnde_museum_afstand_in_km', 'museum_aantal_binnen_5_km', 'museum_aantal_binnen_10_km', 'museum_aantal_binnen_20_km', 'dichtstbijzijnde_theater_afstand_in_km', 'theater_aantal_binnen_5_km', 'theater_aantal_binnen_10_km', 'theater_aantal_binnen_20_km', 'dichtstbijzijnde_bibliotheek_afstand_in_km', 'dichtstbijzijnde_kunstijsbaan_afstand_in_km', 'dichtstbijzijnde_poppodium_afstand_in_km', 'dichtstbijzijnde_sauna_afstand_in_km', 'dichtstbijzijnde_zonnebank_afstand_in_km', 'dichtstbijzijnde_zwembad_afstand_in_km', 'dichtstbijzijnde_basisonderwijs_afstand_in_km', 'basisonderwijs_aantal_binnen ...
#
# Datatypes of CBS gpkg: crs28992res500m                                    object
# aantal_inwoners                                   float64
# aantal_mannen                                     float64
# aantal_vrouwen                                    float64
# aantal_inwoners_0_tot_15_jaar                     float64
#                                                    ...
# dichtstbijzijnde_apotheek_afstand_in_km           float64
# dichtstbijzijnde_huisartsenpost_afstand_in_km     float64
# omgevingsadressendichtheid                        float64
# stedelijkheid                                     float64
# geometry                                         geometry
# Length: 137, dtype: object
#
# Null values of CBS gpkg: crs28992res500m                                      0
# aantal_inwoners                                  63922
# aantal_mannen                                    63922
# aantal_vrouwen                                   63922
# aantal_inwoners_0_tot_15_jaar                    63922
#                                                  ...
# dichtstbijzijnde_apotheek_afstand_in_km          63922
# dichtstbijzijnde_huisartsenpost_afstand_in_km    63922
# omgevingsadressendichtheid                       63922
# stedelijkheid                                    63922
# geometry                                             0
# Length: 137, dtype: int64
#
# Negative (null) values of CBS gpkg: crs28992res500m                                      0
# aantal_inwoners                                  16088
# aantal_mannen                                    29393
# aantal_vrouwen                                   31411
# aantal_inwoners_0_tot_15_jaar                    53388
#                                                  ...
# dichtstbijzijnde_apotheek_afstand_in_km              0
# dichtstbijzijnde_huisartsenpost_afstand_in_km        0
# omgevingsadressendichtheid                          58
# stedelijkheid                                       58
# geometry                                             0
# Length: 137, dtype: int64
#
# Column 'crs28992res500m':  total = 0
# Column 'aantal_inwoners':  total = 80010
# Column 'aantal_mannen':  total = 93315
# Column 'aantal_vrouwen':  total = 95333
# Column 'aantal_inwoners_0_tot_15_jaar':  total = 117310
# Column 'aantal_inwoners_15_tot_25_jaar':  total = 118386
# Column 'aantal_inwoners_25_tot_45_jaar':  total = 114223
# Column 'aantal_inwoners_45_tot_65_jaar':  total = 103112
# Column 'aantal_inwoners_65_jaar_en_ouder':  total = 112220
# Column 'aantal_geboorten':  total = 63922
# Column 'percentage_geb_nederland_herkomst_nederland':  total = 95633
# Column 'percentage_geb_nederland_herkomst_overig_europa':  total = 132794
# Column 'percentage_geb_nederland_herkomst_buiten_europa':  total = 132719
# Column 'percentage_geb_buiten_nederland_herkomst_europa':  total = 131451
# Column 'percentage_geb_buiten_nederland_herkmst_buiten_europa':  total = 132702
# Column 'aantal_part_huishoudens':  total = 100251
# Column 'aantal_eenpersoonshuishoudens':  total = 122766
# Column 'aantal_meerpersoonshuishoudens_zonder_kind':  total = 118086
# Column 'aantal_eenouderhuishoudens':  total = 134149
# Column 'aantal_tweeouderhuishoudens':  total = 119235
# Column 'gemiddelde_huishoudensgrootte':  total = 100251
# Column 'aantal_woningen':  total = 101034
# Column 'aantal_woningen_bouwjaar_voor_1945':  total = 127440
# Column 'aantal_woningen_bouwjaar_45_tot_65':  total = 135664
# Column 'aantal_woningen_bouwjaar_65_tot_75':  total = 136796
# Column 'aantal_woningen_bouwjaar_75_tot_85':  total = 137596
# Column 'aantal_woningen_bouwjaar_85_tot_95':  total = 137493
# Column 'aantal_woningen_bouwjaar_95_tot_05':  total = 138183
# Column 'aantal_woningen_bouwjaar_05_tot_15':  total = 140407
# Column 'aantal_woningen_bouwjaar_15_en_later':  total = 141697
# Column 'aantal_meergezins_woningen':  total = 135000
# Column 'percentage_koopwoningen':  total = 115969
# Column 'percentage_huurwoningen':  total = 129557
# Column 'aantal_huurwoningen_in_bezit_woningcorporaties':  total = 134530
# Column 'aantal_niet_bewoonde_woningen':  total = 137652
# Column 'gemiddelde_woz_waarde_woning':  total = 103925
# Column 'gemiddeld_gasverbruik_woning':  total = 63922
# Column 'gemiddeld_elektriciteitsverbruik_woning':  total = 63922
# Column 'gemiddeld_inkomen_huishouden':  total = 63922
# Column 'percentage_laag_inkomen_huishouden':  total = 63922
# Column 'percentage_hoog_inkomen_huishouden':  total = 63922
# Column 'aantal_personen_met_uitkering_onder_aowlft':  total = 129802
# Column 'dichtstbijzijnde_grote_supermarkt_afstand_in_km':  total = 63922
# Column 'grote_supermarkt_aantal_binnen_1_km':  total = 63922
# Column 'grote_supermarkt_aantal_binnen_3_km':  total = 63922
# Column 'grote_supermarkt_aantal_binnen_5_km':  total = 63922
# Column 'dichtstbijzijnde_winkels_ov_dagel_levensm_afst_in_km':  total = 63922
# Column 'winkels_ov_dagel_levensm_aantal_binnen_1_km':  total = 63922
# Column 'winkels_ov_dagel_levensm_aantal_binnen_3_km':  total = 63922
# Column 'winkels_ov_dagel_levensm_aantal_binnen_5_km':  total = 63922
# Column 'dichtstbijzijnde_warenhuis_afstand_in_km':  total = 63922
# Column 'warenhuis_aantal_binnen_5_km':  total = 63922
# Column 'warenhuis_aantal_binnen_10_km':  total = 63922
# Column 'warenhuis_aantal_binnen_20_km':  total = 63922
# Column 'dichtstbijzijnde_cafe_afstand_in_km':  total = 63922
# Column 'cafe_aantal_binnen_1_km':  total = 63922
# Column 'cafe_aantal_binnen_3_km':  total = 63922
# Column 'cafe_aantal_binnen_5_km':  total = 63922
# Column 'dichtstbijzijnde_cafetaria_afstand_in_km':  total = 63922
# Column 'cafetaria_aantal_binnen_1_km':  total = 63922
# Column 'cafetaria_aantal_binnen_3_km':  total = 63922
# Column 'cafetaria_aantal_binnen_5_km':  total = 63922
# Column 'dichtstbijzijnde_hotel_afstand_in_km':  total = 63922
# Column 'hotel_aantal_binnen_5_km':  total = 63922
# Column 'hotel_aantal_binnen_10_km':  total = 63922
# Column 'hotel_aantal_binnen_20_km':  total = 63922
# Column 'dichtstbijzijnde_restaurant_afstand_in_km':  total = 63922
# Column 'restaurant_aantal_binnen_1_km':  total = 63922
# Column 'restaurant_aantal_binnen_3_km':  total = 63922
# Column 'restaurant_aantal_binnen_5_km':  total = 63922
# Column 'dichtstbijzijnde_buitenschoolse_opvang_afstand_in_km':  total = 63922
# Column 'buitenschoolse_opvang_aantal_binnen_1_km':  total = 63922
# Column 'buitenschoolse_opvang_aantal_binnen_3_km':  total = 63922
# Column 'buitenschoolse_opvang_aantal_binnen_5_km':  total = 63922
# Column 'dichtstbijzijnde_kinderdagverblijf_afstand_in_km':  total = 63922
# Column 'kinderdagverblijf_aantal_binnen_1_km':  total = 63922
# Column 'kinderdagverblijf_aantal_binnen_3_km':  total = 63922
# Column 'kinderdagverblijf_aantal_binnen_5_km':  total = 63922
# Column 'dichtstbijzijnde_brandweerkazerne_afstand_in_km':  total = 63922
# Column 'dichtstbijzijnde_oprit_hoofdverkeersweg_afstand_in_km':  total = 63922
# Column 'dichtstbijzijnde_overstapstation_afstand_in_km':  total = 63922
# Column 'dichtstbijzijnde_treinstation_afstand_in_km':  total = 63922
# Column 'dichtstbijzijnde_attractiepark_afstand_in_km':  total = 63922
# Column 'attractiepark_aantal_binnen_10_km':  total = 63922
# Column 'attractiepark_aantal_binnen_20_km':  total = 63922
# Column 'attractiepark_aantal_binnen_50_km':  total = 63922
# Column 'dichtstbijzijnde_bioscoop_afstand_in_km':  total = 63922
# Column 'bioscoop_aantal_binnen_5_km':  total = 63922
# Column 'bioscoop_aantal_binnen_10_km':  total = 63922
# Column 'bioscoop_aantal_binnen_20_km':  total = 63922
# Column 'dichtstbijzijnde_museum_afstand_in_km':  total = 63922
# Column 'museum_aantal_binnen_5_km':  total = 63922
# Column 'museum_aantal_binnen_10_km':  total = 63922
# Column 'museum_aantal_binnen_20_km':  total = 63922
# Column 'dichtstbijzijnde_theater_afstand_in_km':  total = 63922
# Column 'theater_aantal_binnen_5_km':  total = 63922
# Column 'theater_aantal_binnen_10_km':  total = 63922
# Column 'theater_aantal_binnen_20_km':  total = 63922
# Column 'dichtstbijzijnde_bibliotheek_afstand_in_km':  total = 63922
# Column 'dichtstbijzijnde_kunstijsbaan_afstand_in_km':  total = 63922
# Column 'dichtstbijzijnde_poppodium_afstand_in_km':  total = 63922
# Column 'dichtstbijzijnde_sauna_afstand_in_km':  total = 63922
# Column 'dichtstbijzijnde_zonnebank_afstand_in_km':  total = 63922
# Column 'dichtstbijzijnde_zwembad_afstand_in_km':  total = 63922
# Column 'dichtstbijzijnde_basisonderwijs_afstand_in_km':  total = 63922
# Column 'basisonderwijs_aantal_binnen_1_km':  total = 63922
# Column 'basisonderwijs_aantal_binnen_3_km':  total = 63922
# Column 'basisonderwijs_aantal_binnen_5_km':  total = 63922
# Column 'dichtstbijzijnde_havo_vwo_afstand_in_km':  total = 63922
# Column 'havo_vwo_aantal_binnen_3_km':  total = 63922
# Column 'havo_vwo_aantal_binnen_5_km':  total = 63922
# Column 'havo_vwo_aantal_binnen_10_km':  total = 63922
# Column 'dichtstbijzijnde_vmbo_afstand_in_km':  total = 63922
# Column 'vmbo_aantal_binnen_3_km':  total = 63922
# Column 'vmbo_aantal_binnen_5_km':  total = 63922
# Column 'vmbo_aantal_binnen_10_km':  total = 63922
# Column 'dichtstbijzijnde_voortgezet_onderwijs_afstand_in_km':  total = 63922
# Column 'voortgezet_onderwijs_aantal_binnen_3_km':  total = 63922
# Column 'voortgezet_onderwijs_aantal_binnen_5_km':  total = 63922
# Column 'voortgezet_onderwijs_aantal_binnen_10_km':  total = 63922
# Column 'dichtstbijzijnde_huisartsenpraktijk_afstand_in_km':  total = 63922
# Column 'huisartsenpraktijk_aantal_binnen_1_km':  total = 63922
# Column 'huisartsenpraktijk_aantal_binnen_3_km':  total = 63922
# Column 'huisartsenpraktijk_aantal_binnen_5_km':  total = 63922
# Column 'dichtstbijzijnde_ziekenh_excl_buitenpoli_afst_in_km':  total = 63922
# Column 'ziekenhuis_excl_buitenpoli_aantal_binnen_5_km':  total = 63922
# Column 'ziekenhuis_excl_buitenpoli_aantal_binnen_10_km':  total = 63922
# Column 'ziekenhuis_excl_buitenpoli_aantal_binnen_20_km':  total = 63922
# Column 'dichtstbijzijnde_ziekenh_incl_buitenpoli_afst_in_km':  total = 63922
# Column 'ziekenhuis_incl_buitenpoli_aantal_binnen_5_km':  total = 63922
# Column 'ziekenhuis_incl_buitenpoli_aantal_binnen_10_km':  total = 63922
# Column 'ziekenhuis_incl_buitenpoli_aantal_binnen_20_km':  total = 63922
# Column 'dichtstbijzijnde_apotheek_afstand_in_km':  total = 63922
# Column 'dichtstbijzijnde_huisartsenpost_afstand_in_km':  total = 63922
# Column 'omgevingsadressendichtheid':  total = 63980
# Column 'stedelijkheid':  total = 63980
# Column 'geometry':  total = 0

# %%
cbs_full.head()
# Out:
#   crs28992res500m  aantal_inwoners  aantal_mannen  aantal_vrouwen  \
# 0      E2260N6190              NaN            NaN             NaN
# 1      E2265N6190              NaN            NaN             NaN
# 2      E2270N6190              NaN            NaN             NaN
# 3      E2275N6190              NaN            NaN             NaN
# 4      E2280N6190              NaN            NaN             NaN
#
#    aantal_inwoners_0_tot_15_jaar  aantal_inwoners_15_tot_25_jaar  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
# 3                            NaN                             NaN
# 4                            NaN                             NaN
#
#    aantal_inwoners_25_tot_45_jaar  aantal_inwoners_45_tot_65_jaar  \
# 0                             NaN                             NaN
# 1                             NaN                             NaN
# 2                             NaN                             NaN
# 3                             NaN                             NaN
# 4                             NaN                             NaN
#
#    aantal_inwoners_65_jaar_en_ouder  aantal_geboorten  ...  \
# 0                               NaN               NaN  ...
# 1                               NaN               NaN  ...
# 2                               NaN               NaN  ...
# 3                               NaN               NaN  ...
# 4                               NaN               NaN  ...
#
#    ziekenhuis_excl_buitenpoli_aantal_binnen_20_km  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    dichtstbijzijnde_ziekenh_incl_buitenpoli_afst_in_km  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ziekenhuis_incl_buitenpoli_aantal_binnen_5_km  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    ziekenhuis_incl_buitenpoli_aantal_binnen_10_km  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    ziekenhuis_incl_buitenpoli_aantal_binnen_20_km  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    dichtstbijzijnde_apotheek_afstand_in_km  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    dichtstbijzijnde_huisartsenpost_afstand_in_km  omgevingsadressendichtheid  \
# 0                                            NaN                         NaN
# 1                                            NaN                         NaN
# 2                                            NaN                         NaN
# 3                                            NaN                         NaN
# 4                                            NaN                         NaN
#
#    stedelijkheid                                           geometry
# 0            NaN  MULTIPOLYGON (((226000 619000, 226000 619500, ...
# 1            NaN  MULTIPOLYGON (((226500 619500, 227000 619500, ...
# 2            NaN  MULTIPOLYGON (((227000 619500, 227500 619500, ...
# 3            NaN  MULTIPOLYGON (((227500 619500, 228000 619500, ...
# 4            NaN  MULTIPOLYGON (((228000 619500, 228500 619500, ...
#
# [5 rows x 137 columns]

# %%
# drop rows where aantal_inwoners is NULL and save to a new dataframe; where inhabitants are 
cbs_no_null_inwoners = cbs_full.dropna(subset =['aantal_inwoners'])
cbs_no_null_inwoners = cbs_no_null_inwoners[cbs_no_null_inwoners['aantal_inwoners'] != -99997.0]
cbs_no_null_inwoners = cbs_no_null_inwoners.reset_index().drop(columns=['index'])

print(f"Shape of cbs_no_null_inwoners: {cbs_no_null_inwoners.shape}")
cbs_no_null_inwoners.head()
# Out:
# Shape of cbs_no_null_inwoners: (71098, 137)
#   crs28992res500m  aantal_inwoners  aantal_mannen  aantal_vrouwen  \
# 0      E2050N6110              5.0       -99997.0        -99997.0
# 1      E2060N6110             15.0           10.0             5.0
# 2      E2055N6105             30.0           10.0            15.0
# 3      E2060N6105            160.0           85.0            75.0
# 4      E2065N6105            365.0          190.0           175.0
#
#    aantal_inwoners_0_tot_15_jaar  aantal_inwoners_15_tot_25_jaar  \
# 0                       -99997.0                        -99997.0
# 1                       -99997.0                        -99997.0
# 2                       -99997.0                        -99997.0
# 3                            5.0                            20.0
# 4                           40.0                            35.0
#
#    aantal_inwoners_25_tot_45_jaar  aantal_inwoners_45_tot_65_jaar  \
# 0                        -99997.0                        -99997.0
# 1                        -99997.0                        -99997.0
# 2                        -99997.0                             5.0
# 3                            40.0                            40.0
# 4                            85.0                           120.0
#
#    aantal_inwoners_65_jaar_en_ouder  aantal_geboorten  ...  \
# 0                          -99997.0          -99995.0  ...
# 1                               5.0          -99995.0  ...
# 2                              15.0          -99995.0  ...
# 3                              55.0          -99995.0  ...
# 4                              90.0          -99995.0  ...
#
#    ziekenhuis_excl_buitenpoli_aantal_binnen_20_km  \
# 0                                        -99995.0
# 1                                        -99995.0
# 2                                        -99995.0
# 3                                        -99995.0
# 4                                        -99995.0
#
#    dichtstbijzijnde_ziekenh_incl_buitenpoli_afst_in_km  \
# 0                                           -99995.0
# 1                                           -99995.0
# 2                                           -99995.0
# 3                                           -99995.0
# 4                                           -99995.0
#
#    ziekenhuis_incl_buitenpoli_aantal_binnen_5_km  \
# 0                                       -99995.0
# 1                                       -99995.0
# 2                                       -99995.0
# 3                                       -99995.0
# 4                                       -99995.0
#
#    ziekenhuis_incl_buitenpoli_aantal_binnen_10_km  \
# 0                                        -99995.0
# 1                                        -99995.0
# 2                                        -99995.0
# 3                                        -99995.0
# 4                                        -99995.0
#
#    ziekenhuis_incl_buitenpoli_aantal_binnen_20_km  \
# 0                                        -99995.0
# 1                                        -99995.0
# 2                                        -99995.0
# 3                                        -99995.0
# 4                                        -99995.0
#
#    dichtstbijzijnde_apotheek_afstand_in_km  \
# 0                                 -99995.0
# 1                                 -99995.0
# 2                                 -99995.0
# 3                                 -99995.0
# 4                                 -99995.0
#
#    dichtstbijzijnde_huisartsenpost_afstand_in_km  omgevingsadressendichtheid  \
# 0                                       -99995.0                       122.0
# 1                                       -99995.0                       366.0
# 2                                       -99995.0                       378.0
# 3                                       -99995.0                       416.0
# 4                                       -99995.0                       387.0
#
#    stedelijkheid                                           geometry
# 0            5.0  MULTIPOLYGON (((205000 611500, 205500 611500, ...
# 1            5.0  MULTIPOLYGON (((206000 611500, 206500 611500, ...
# 2            5.0  MULTIPOLYGON (((205500 611000, 206000 611000, ...
# 3            5.0  MULTIPOLYGON (((206000 611000, 206500 611000, ...
# 4            5.0  MULTIPOLYGON (((206500 611000, 207000 611000, ...
#
# [5 rows x 137 columns]

# %%
# show all columns - choose ones to drop
cbs_no_null_inwoners.columns.tolist()
# Out:
# ['crs28992res500m',
#  'aantal_inwoners',
#  'aantal_mannen',
#  'aantal_vrouwen',
#  'aantal_inwoners_0_tot_15_jaar',
#  'aantal_inwoners_15_tot_25_jaar',
#  'aantal_inwoners_25_tot_45_jaar',
#  'aantal_inwoners_45_tot_65_jaar',
#  'aantal_inwoners_65_jaar_en_ouder',
#  'aantal_geboorten',
#  'percentage_geb_nederland_herkomst_nederland',
#  'percentage_geb_nederland_herkomst_overig_europa',
#  'percentage_geb_nederland_herkomst_buiten_europa',
#  'percentage_geb_buiten_nederland_herkomst_europa',
#  'percentage_geb_buiten_nederland_herkmst_buiten_europa',
#  'aantal_part_huishoudens',
#  'aantal_eenpersoonshuishoudens',
#  'aantal_meerpersoonshuishoudens_zonder_kind',
#  'aantal_eenouderhuishoudens',
#  'aantal_tweeouderhuishoudens',
#  'gemiddelde_huishoudensgrootte',
#  'aantal_woningen',
#  'aantal_woningen_bouwjaar_voor_1945',
#  'aantal_woningen_bouwjaar_45_tot_65',
#  'aantal_woningen_bouwjaar_65_tot_75',
#  'aantal_woningen_bouwjaar_75_tot_85',
#  'aantal_woningen_bouwjaar_85_tot_95',
#  'aantal_woningen_bouwjaar_95_tot_05',
#  'aantal_woningen_bouwjaar_05_tot_15',
#  'aantal_woningen_bouwjaar_15_en_later',
#  'aantal_meergezins_woningen',
#  'percentage_koopwoningen',
#  'percentage_huurwoningen',
#  'aantal_huurwoningen_in_bezit_woningcorporaties',
#  'aantal_niet_bewoonde_woningen',
#  'gemiddelde_woz_waarde_woning',
#  'gemiddeld_gasverbruik_woning',
#  'gemiddeld_elektriciteitsverbruik_woning',
#  'gemiddeld_inkomen_huishouden',
#  'percentage_laag_inkomen_huishouden',
#  'percentage_hoog_inkomen_huishouden',
#  'aantal_personen_met_uitkering_onder_aowlft',
#  'dichtstbijzijnde_grote_supermarkt_afstand_in_km',
#  'grote_supermarkt_aantal_binnen_1_km',
#  'grote_supermarkt_aantal_binnen_3_km',
#  'grote_supermarkt_aantal_binnen_5_km',
#  'dichtstbijzijnde_winkels_ov_dagel_levensm_afst_in_km',
#  'winkels_ov_dagel_levensm_aantal_binnen_1_km',
#  'winkels_ov_dagel_levensm_aantal_binnen_3_km',
#  'winkels_ov_dagel_levensm_aantal_binnen_5_km',
#  'dichtstbijzijnde_warenhuis_afstand_in_km',
#  'warenhuis_aantal_binnen_5_km',
#  'warenhuis_aantal_binnen_10_km',
#  'warenhuis_aantal_binnen_20_km',
#  'dichtstbijzijnde_cafe_afstand_in_km',
#  'cafe_aantal_binnen_1_km',
#  'cafe_aantal_binnen_3_km',
#  'cafe_aantal_binnen_5_km',
#  'dichtstbijzijnde_cafetaria_afstand_in_km',
#  'cafetaria_aantal_binnen_1_km',
#  'cafetaria_aantal_binnen_3_km',
#  'cafetaria_aantal_binnen_5_km',
#  'dichtstbijzijnde_hotel_afstand_in_km',
#  'hotel_aantal_binnen_5_km',
#  'hotel_aantal_binnen_10_km',
#  'hotel_aantal_binnen_20_km',
#  'dichtstbijzijnde_restaurant_afstand_in_km',
#  'restaurant_aantal_binnen_1_km',
#  'restaurant_aantal_binnen_3_km',
#  'restaurant_aantal_binnen_5_km',
#  'dichtstbijzijnde_buitenschoolse_opvang_afstand_in_km',
#  'buitenschoolse_opvang_aantal_binnen_1_km',
#  'buitenschoolse_opvang_aantal_binnen_3_km',
#  'buitenschoolse_opvang_aantal_binnen_5_km',
#  'dichtstbijzijnde_kinderdagverblijf_afstand_in_km',
#  'kinderdagverblijf_aantal_binnen_1_km',
#  'kinderdagverblijf_aantal_binnen_3_km',
#  'kinderdagverblijf_aantal_binnen_5_km',
#  'dichtstbijzijnde_brandweerkazerne_afstand_in_km',
#  'dichtstbijzijnde_oprit_hoofdverkeersweg_afstand_in_km',
#  'dichtstbijzijnde_overstapstation_afstand_in_km',
#  'dichtstbijzijnde_treinstation_afstand_in_km',
#  'dichtstbijzijnde_attractiepark_afstand_in_km',
#  'attractiepark_aantal_binnen_10_km',
#  'attractiepark_aantal_binnen_20_km',
#  'attractiepark_aantal_binnen_50_km',
#  'dichtstbijzijnde_bioscoop_afstand_in_km',
#  'bioscoop_aantal_binnen_5_km',
#  'bioscoop_aantal_binnen_10_km',
#  'bioscoop_aantal_binnen_20_km',
#  'dichtstbijzijnde_museum_afstand_in_km',
#  'museum_aantal_binnen_5_km',
#  'museum_aantal_binnen_10_km',
#  'museum_aantal_binnen_20_km',
#  'dichtstbijzijnde_theater_afstand_in_km',
#  'theater_aantal_binnen_5_km',
#  'theater_aantal_binnen_10_km',
#  'theater_aantal_binnen_20_km',
#  'dichtstbijzijnde_bibliotheek_afstand_in_km',
#  'dichtstbijzijnde_kunstijsbaan_afstand_in_km',
#  'dichtstbijzijnde_poppodium_afstand_in_km',
#  'dichtstbijzijnde_sauna_afstand_in_km',
#  'dichtstbijzijnde_zonnebank_afstand_in_km',
#  'dichtstbijzijnde_zwembad_afstand_in_km',
#  'dichtstbijzijnde_basisonderwijs_afstand_in_km',
#  'basisonderwijs_aantal_binnen_1_km',
#  'basisonderwijs_aantal_binnen_3_km',
#  'basisonderwijs_aantal_binnen_5_km',
#  'dichtstbijzijnde_havo_vwo_afstand_in_km',
#  'havo_vwo_aantal_binnen_3_km',
#  'havo_vwo_aantal_binnen_5_km',
#  'havo_vwo_aantal_binnen_10_km',
#  'dichtstbijzijnde_vmbo_afstand_in_km',
#  'vmbo_aantal_binnen_3_km',
#  'vmbo_aantal_binnen_5_km',
#  'vmbo_aantal_binnen_10_km',
#  'dichtstbijzijnde_voortgezet_onderwijs_afstand_in_km',
#  'voortgezet_onderwijs_aantal_binnen_3_km',
#  'voortgezet_onderwijs_aantal_binnen_5_km',
#  'voortgezet_onderwijs_aantal_binnen_10_km',
#  'dichtstbijzijnde_huisartsenpraktijk_afstand_in_km',
#  'huisartsenpraktijk_aantal_binnen_1_km',
#  'huisartsenpraktijk_aantal_binnen_3_km',
#  'huisartsenpraktijk_aantal_binnen_5_km',
#  'dichtstbijzijnde_ziekenh_excl_buitenpoli_afst_in_km',
#  'ziekenhuis_excl_buitenpoli_aantal_binnen_5_km',
#  'ziekenhuis_excl_buitenpoli_aantal_binnen_10_km',
#  'ziekenhuis_excl_buitenpoli_aantal_binnen_20_km',
#  'dichtstbijzijnde_ziekenh_incl_buitenpoli_afst_in_km',
#  'ziekenhuis_incl_buitenpoli_aantal_binnen_5_km',
#  'ziekenhuis_incl_buitenpoli_aantal_binnen_10_km',
#  'ziekenhuis_incl_buitenpoli_aantal_binnen_20_km',
#  'dichtstbijzijnde_apotheek_afstand_in_km',
#  'dichtstbijzijnde_huisartsenpost_afstand_in_km',
#  'omgevingsadressendichtheid',
#  'stedelijkheid',
#  'geometry']

# %%
# select only for relevant columns
cols = [
 'crs28992res500m',
 'aantal_inwoners',
 'aantal_mannen',
 'aantal_vrouwen',
 'aantal_inwoners_0_tot_15_jaar',
 'aantal_inwoners_15_tot_25_jaar',
 'aantal_inwoners_25_tot_45_jaar',
 'aantal_inwoners_45_tot_65_jaar',
 'aantal_inwoners_65_jaar_en_ouder',
 'aantal_part_huishoudens',
 'aantal_eenpersoonshuishoudens',
 'aantal_meerpersoonshuishoudens_zonder_kind',
 'aantal_eenouderhuishoudens',
 'aantal_tweeouderhuishoudens',
 'gemiddelde_huishoudensgrootte',
 'aantal_woningen',
 'aantal_meergezins_woningen',
 'percentage_koopwoningen',
 'percentage_huurwoningen',
 'aantal_huurwoningen_in_bezit_woningcorporaties',
 'aantal_niet_bewoonde_woningen',
 'gemiddelde_woz_waarde_woning',
 'gemiddeld_inkomen_huishouden',
 'percentage_laag_inkomen_huishouden',
 'percentage_hoog_inkomen_huishouden',
 'aantal_personen_met_uitkering_onder_aowlft',
 'geometry'
 ]
cbs_filtered = cbs_no_null_inwoners[cols].copy()
 
print("Shade of cbs_filtered:", cbs_filtered.shape)
cbs_filtered.head(10)
# Out:
# Shade of cbs_filtered: (71098, 27)
#   crs28992res500m  aantal_inwoners  aantal_mannen  aantal_vrouwen  \
# 0      E2050N6110              5.0       -99997.0        -99997.0
# 1      E2060N6110             15.0           10.0             5.0
# 2      E2055N6105             30.0           10.0            15.0
# 3      E2060N6105            160.0           85.0            75.0
# 4      E2065N6105            365.0          190.0           175.0
# 5      E2070N6105             30.0           15.0            15.0
# 6      E2075N6105             15.0            5.0             5.0
# 7      E2085N6105              5.0       -99997.0        -99997.0
# 8      E2055N6100             10.0            5.0             5.0
# 9      E2060N6100            145.0           85.0            60.0
#
#    aantal_inwoners_0_tot_15_jaar  aantal_inwoners_15_tot_25_jaar  \
# 0                       -99997.0                        -99997.0
# 1                       -99997.0                        -99997.0
# 2                       -99997.0                        -99997.0
# 3                            5.0                            20.0
# 4                           40.0                            35.0
# 5                       -99997.0                        -99997.0
# 6                       -99997.0                        -99997.0
# 7                       -99997.0                        -99997.0
# 8                       -99997.0                        -99997.0
# 9                       -99997.0                            25.0
#
#    aantal_inwoners_25_tot_45_jaar  aantal_inwoners_45_tot_65_jaar  \
# 0                        -99997.0                        -99997.0
# 1                        -99997.0                        -99997.0
# 2                        -99997.0                             5.0
# 3                            40.0                            40.0
# 4                            85.0                           120.0
# 5                        -99997.0                            15.0
# 6                        -99997.0                        -99997.0
# 7                        -99997.0                        -99997.0
# 8                        -99997.0                        -99997.0
# 9                            45.0                            25.0
#
#    aantal_inwoners_65_jaar_en_ouder  aantal_part_huishoudens  ...  \
# 0                          -99997.0                 -99997.0  ...
# 1                               5.0                     10.0  ...
# 2                              15.0                     15.0  ...
# 3                              55.0                    110.0  ...
# 4                              90.0                    205.0  ...
# 5                              10.0                     15.0  ...
# 6                          -99997.0                      5.0  ...
# 7                          -99997.0                 -99997.0  ...
# 8                               5.0                      5.0  ...
# 9                              50.0                    110.0  ...
#
#    percentage_koopwoningen  percentage_huurwoningen  \
# 0                 -99997.0                 -99997.0
# 1                 -99997.0                 -99997.0
# 2                     70.0                     30.0
# 3                     50.0                     50.0
# 4                     50.0                     50.0
# 5                    100.0                 -99997.0
# 6                 -99997.0                 -99997.0
# 7                 -99997.0                 -99997.0
# 8                 -99997.0                 -99997.0
# 9                     70.0                     30.0
#
#    aantal_huurwoningen_in_bezit_woningcorporaties  \
# 0                                        -99997.0
# 1                                        -99997.0
# 2                                        -99997.0
# 3                                             5.0
# 4                                            95.0
# 5                                        -99997.0
# 6                                        -99997.0
# 7                                        -99997.0
# 8                                        -99997.0
# 9                                             5.0
#
#    aantal_niet_bewoonde_woningen  gemiddelde_woz_waarde_woning  \
# 0                       -99997.0                      -99997.0
# 1                       -99997.0                         741.0
# 2                            5.0                         677.0
# 3                           65.0                         400.0
# 4                           30.0                         349.0
# 5                       -99997.0                         505.0
# 6                       -99997.0                      -99997.0
# 7                       -99997.0                      -99997.0
# 8                       -99997.0                         546.0
# 9                           25.0                         399.0
#
#    gemiddeld_inkomen_huishouden  percentage_laag_inkomen_huishouden  \
# 0                      -99995.0                            -99995.0
# 1                      -99995.0                            -99995.0
# 2                      -99995.0                            -99995.0
# 3                      -99995.0                            -99995.0
# 4                      -99995.0                            -99995.0
# 5                      -99995.0                            -99995.0
# 6                      -99995.0                            -99995.0
# 7                      -99995.0                            -99995.0
# 8                      -99995.0                            -99995.0
# 9                      -99995.0                            -99995.0
#
#    percentage_hoog_inkomen_huishouden  \
# 0                            -99995.0
# 1                            -99995.0
# 2                            -99995.0
# 3                            -99995.0
# 4                            -99995.0
# 5                            -99995.0
# 6                            -99995.0
# 7                            -99995.0
# 8                            -99995.0
# 9                            -99995.0
#
#    aantal_personen_met_uitkering_onder_aowlft  \
# 0                                    -99997.0
# 1                                    -99997.0
# 2                                    -99997.0
# 3                                    -99997.0
# 4                                        15.0
# 5                                         5.0
# 6                                    -99997.0
# 7                                    -99997.0
# 8                                    -99997.0
# 9                                         5.0
#
#                                             geometry
# 0  MULTIPOLYGON (((205000 611500, 205500 611500, ...
# 1  MULTIPOLYGON (((206000 611500, 206500 611500, ...
# 2  MULTIPOLYGON (((205500 611000, 206000 611000, ...
# 3  MULTIPOLYGON (((206000 611000, 206500 611000, ...
# 4  MULTIPOLYGON (((206500 611000, 207000 611000, ...
# 5  MULTIPOLYGON (((207000 611000, 207500 611000, ...
# 6  MULTIPOLYGON (((207500 611000, 208000 611000, ...
# 7  MULTIPOLYGON (((208500 611000, 209000 611000, ...
# 8  MULTIPOLYGON (((205500 610500, 206000 610500, ...
# 9  MULTIPOLYGON (((206000 610500, 206500 610500, ...
#
# [10 rows x 27 columns]

# %%
# identify how many null values are in each column (-99997.0 or -99995.0)
mask = (cbs_filtered == -99997.0) | (cbs_filtered == -99995.0)
fake_null_values = mask.sum()
fake_null_values[fake_null_values > 0]
# Out:
# aantal_mannen                                     13305
# aantal_vrouwen                                    15323
# aantal_inwoners_0_tot_15_jaar                     37300
# aantal_inwoners_15_tot_25_jaar                    38376
# aantal_inwoners_25_tot_45_jaar                    34213
# aantal_inwoners_45_tot_65_jaar                    23102
# aantal_inwoners_65_jaar_en_ouder                  32210
# aantal_part_huishoudens                           20241
# aantal_eenpersoonshuishoudens                     42756
# aantal_meerpersoonshuishoudens_zonder_kind        38076
# aantal_eenouderhuishoudens                        54139
# aantal_tweeouderhuishoudens                       39225
# gemiddelde_huishoudensgrootte                     20241
# aantal_woningen                                   21111
# aantal_meergezins_woningen                        55004
# percentage_koopwoningen                           35975
# percentage_huurwoningen                           49561
# aantal_huurwoningen_in_bezit_woningcorporaties    54520
# aantal_niet_bewoonde_woningen                     57688
# gemiddelde_woz_waarde_woning                      23993
# gemiddeld_inkomen_huishouden                      71098
# percentage_laag_inkomen_huishouden                71098
# percentage_hoog_inkomen_huishouden                71098
# aantal_personen_met_uitkering_onder_aowlft        49792
# dtype: int64

# %%
# further delete columns that are all fake null values
cols_to_drop = [
    'gemiddeld_inkomen_huishouden',
    'percentage_laag_inkomen_huishouden',
    'percentage_hoog_inkomen_huishouden'
]
cbs_filtered = cbs_filtered.drop(columns=cols_to_drop)
cbs_filtered.shape
# Out:
# (71098, 24)

# %%
# change all fake null values to NaN
cbs_filtered = cbs_filtered.replace([-99997.0, -99995.0], np.nan)
cbs_filtered.head(15)
# Out:
#    crs28992res500m  aantal_inwoners  aantal_mannen  aantal_vrouwen  \
# 0       E2050N6110              5.0            NaN             NaN
# 1       E2060N6110             15.0           10.0             5.0
# 2       E2055N6105             30.0           10.0            15.0
# 3       E2060N6105            160.0           85.0            75.0
# 4       E2065N6105            365.0          190.0           175.0
# 5       E2070N6105             30.0           15.0            15.0
# 6       E2075N6105             15.0            5.0             5.0
# 7       E2085N6105              5.0            NaN             NaN
# 8       E2055N6100             10.0            5.0             5.0
# 9       E2060N6100            145.0           85.0            60.0
# 10      E2065N6100            185.0           95.0            85.0
# 11      E2075N6100             15.0            5.0            10.0
# 12      E2085N6100              5.0            NaN             NaN
# 13      E1805N6075             25.0           10.0            15.0
# 14      E1825N6075             30.0           25.0             5.0
#
#     aantal_inwoners_0_tot_15_jaar  aantal_inwoners_15_tot_25_jaar  \
# 0                             NaN                             NaN
# 1                             NaN                             NaN
# 2                             NaN                             NaN
# 3                             5.0                            20.0
# 4                            40.0                            35.0
# 5                             NaN                             NaN
# 6                             NaN                             NaN
# 7                             NaN                             NaN
# 8                             NaN                             NaN
# 9                             NaN                            25.0
# 10                           30.0                            15.0
# 11                            5.0                             NaN
# 12                            NaN                             NaN
# 13                            NaN                             NaN
# 14                            NaN                             5.0
#
#     aantal_inwoners_25_tot_45_jaar  aantal_inwoners_45_tot_65_jaar  \
# 0                              NaN                             NaN
# 1                              NaN                             NaN
# 2                              NaN                             5.0
# 3                             40.0                            40.0
# 4                             85.0                           120.0
# 5                              NaN                            15.0
# 6                              NaN                             NaN
# 7                              NaN                             NaN
# 8                              NaN                             NaN
# 9                             45.0                            25.0
# 10                            35.0                            55.0
# 11                             NaN                             NaN
# 12                             NaN                             NaN
# 13                             NaN                             5.0
# 14                            10.0                            10.0
#
#     aantal_inwoners_65_jaar_en_ouder  aantal_part_huishoudens  ...  \
# 0                                NaN                      NaN  ...
# 1                                5.0                     10.0  ...
# 2                               15.0                     15.0  ...
# 3                               55.0                    110.0  ...
# 4                               90.0                    205.0  ...
# 5                               10.0                     15.0  ...
# 6                                NaN                      5.0  ...
# 7                                NaN                      NaN  ...
# 8                                5.0                      5.0  ...
# 9                               50.0                    110.0  ...
# 10                              45.0                     95.0  ...
# 11                               NaN                      5.0  ...
# 12                               NaN                      NaN  ...
# 13                              15.0                     20.0  ...
# 14                               NaN                     20.0  ...
#
#     gemiddelde_huishoudensgrootte  aantal_woningen  \
# 0                             NaN              NaN
# 1                             1.4              5.0
# 2                             1.8             20.0
# 3                             1.5            145.0
# 4                             1.8            225.0
# 5                             2.1             15.0
# 6                             1.9              NaN
# 7                             NaN              NaN
# 8                             1.7             10.0
# 9                             1.3             85.0
# 10                            2.0             85.0
# 11                            3.0              NaN
# 12                            NaN              NaN
# 13                            1.2             20.0
# 14                            1.5              5.0
#
#     aantal_meergezins_woningen  percentage_koopwoningen  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          NaN                     70.0
# 3                         70.0                     50.0
# 4                         45.0                     50.0
# 5                          NaN                    100.0
# 6                          NaN                      NaN
# 7                          NaN                      NaN
# 8                          NaN                      NaN
# 9                         30.0                     70.0
# 10                         NaN                     40.0
# 11                         NaN                      NaN
# 12                         NaN                      NaN
# 13                        20.0                     70.0
# 14                         NaN                      NaN
#
#     percentage_huurwoningen  aantal_huurwoningen_in_bezit_woningcorporaties  \
# 0                       NaN                                             NaN
# 1                       NaN                                             NaN
# 2                      30.0                                             NaN
# 3                      50.0                                             5.0
# 4                      50.0                                            95.0
# 5                       NaN                                             NaN
# 6                       NaN                                             NaN
# 7                       NaN                                             NaN
# 8                       NaN                                             NaN
# 9                      30.0                                             5.0
# 10                     60.0                                            50.0
# 11                      NaN                                             NaN
# 12                      NaN                                             NaN
# 13                     30.0                                             NaN
# 14                      NaN                                             NaN
#
#     aantal_niet_bewoonde_woningen  gemiddelde_woz_waarde_woning  \
# 0                             NaN                           NaN
# 1                             NaN                         741.0
# 2                             5.0                         677.0
# 3                            65.0                         400.0
# 4                            30.0                         349.0
# 5                             NaN                         505.0
# 6                             NaN                           NaN
# 7                             NaN                           NaN
# 8                             NaN                         546.0
# 9                            25.0                         399.0
# 10                            NaN                         324.0
# 11                            NaN                           NaN
# 12                            NaN                           NaN
# 13                           10.0                         414.0
# 14                            NaN                         385.0
#
#     aantal_personen_met_uitkering_onder_aowlft  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                         15.0
# 5                                          5.0
# 6                                          NaN
# 7                                          NaN
# 8                                          NaN
# 9                                          5.0
# 10                                        10.0
# 11                                         NaN
# 12                                         NaN
# 13                                         NaN
# 14                                         NaN
#
#                                              geometry
# 0   MULTIPOLYGON (((205000 611500, 205500 611500, ...
# 1   MULTIPOLYGON (((206000 611500, 206500 611500, ...
# 2   MULTIPOLYGON (((205500 611000, 206000 611000, ...
# 3   MULTIPOLYGON (((206000 611000, 206500 611000, ...
# 4   MULTIPOLYGON (((206500 611000, 207000 611000, ...
# 5   MULTIPOLYGON (((207000 611000, 207500 611000, ...
# 6   MULTIPOLYGON (((207500 611000, 208000 611000, ...
# 7   MULTIPOLYGON (((208500 611000, 209000 611000, ...
# 8   MULTIPOLYGON (((205500 610500, 206000 610500, ...
# 9   MULTIPOLYGON (((206000 610500, 206500 610500, ...
# 10  MULTIPOLYGON (((206500 610500, 207000 610500, ...
# 11  MULTIPOLYGON (((207500 610500, 208000 610500, ...
# 12  MULTIPOLYGON (((208500 610500, 209000 610500, ...
# 13  MULTIPOLYGON (((180500 608000, 181000 608000, ...
# 14  MULTIPOLYGON (((182500 608000, 183000 608000, ...
#
# [15 rows x 24 columns]

# %%
# find the min and max values of each column
cbs_filtered.describe()
# Out:
#        aantal_inwoners  aantal_mannen  aantal_vrouwen  \
# count     71098.000000   57793.000000    55775.000000
# mean        249.841346     151.925060      159.390856
# std         517.417027     276.420832      287.044526
# min           5.000000       5.000000        5.000000
# 25%          10.000000      10.000000       10.000000
# 50%          25.000000      20.000000       25.000000
# 75%         185.000000     160.000000      175.000000
# max        7290.000000    3560.000000     3730.000000
#
#        aantal_inwoners_0_tot_15_jaar  aantal_inwoners_15_tot_25_jaar  \
# count                   33798.000000                    32722.000000
# mean                       78.901562                       64.969592
# std                       105.618888                      100.042157
# min                         5.000000                        5.000000
# 25%                        10.000000                       10.000000
# 50%                        30.000000                       25.000000
# 75%                       115.000000                       85.000000
# max                      1215.000000                     1915.000000
#
#        aantal_inwoners_25_tot_45_jaar  aantal_inwoners_45_tot_65_jaar  \
# count                    36885.000000                    47996.000000
# mean                       120.304053                       98.099008
# std                        208.103924                      150.843439
# min                          5.000000                        5.000000
# 25%                         10.000000                       10.000000
# 50%                         35.000000                       25.000000
# 75%                        155.000000                      130.000000
# max                       3565.000000                     1715.000000
#
#        aantal_inwoners_65_jaar_en_ouder  aantal_part_huishoudens  \
# count                      38888.000000             50857.000000
# mean                          90.775175               161.004188
# std                          124.299778               300.945399
# min                            5.000000                 5.000000
# 25%                           10.000000                10.000000
# 50%                           30.000000                25.000000
# 75%                          135.000000               180.000000
# max                         1180.000000              4880.000000
#
#        aantal_eenpersoonshuishoudens  ...  aantal_tweeouderhuishoudens  \
# count                   28342.000000  ...                 31873.000000
# mean                      113.167561  ...                    61.447777
# std                       200.988674  ...                    72.070477
# min                         5.000000  ...                     5.000000
# 25%                        10.000000  ...                    10.000000
# 50%                        40.000000  ...                    30.000000
# 75%                       130.000000  ...                    90.000000
# max                      3230.000000  ...                   710.000000
#
#        gemiddelde_huishoudensgrootte  aantal_woningen  \
# count                   50857.000000     49987.000000
# mean                        2.405331       160.838818
# std                         0.520143       289.838016
# min                         1.000000         5.000000
# 25%                         2.100000        10.000000
# 50%                         2.400000        25.000000
# 75%                         2.700000       185.000000
# max                         6.300000      4775.000000
#
#        aantal_meergezins_woningen  percentage_koopwoningen  \
# count                16094.000000             35123.000000
# mean                   182.307071                75.200011
# std                    334.772524                21.704507
# min                      5.000000                 0.000000
# 25%                     15.000000                60.000000
# 50%                     60.000000                80.000000
# 75%                    190.000000                90.000000
# max                   4770.000000               100.000000
#
#        percentage_huurwoningen  \
# count             21537.000000
# mean                 36.204207
# std                  21.732829
# min                   0.000000
# 25%                  20.000000
# 50%                  30.000000
# 75%                  50.000000
# max                 100.000000
#
#        aantal_huurwoningen_in_bezit_woningcorporaties  \
# count                                    16578.000000
# mean                                       139.131982
# std                                        186.455358
# min                                          5.000000
# 25%                                         25.000000
# 50%                                         75.000000
# 75%                                        175.000000
# max                                       2175.000000
#
#        aantal_niet_bewoonde_woningen  gemiddelde_woz_waarde_woning  \
# count                   13410.000000                  47105.000000
# mean                       22.359806                    462.427322
# std                        31.587263                    210.061907
# min                         5.000000                     12.000000
# 25%                         5.000000                    335.000000
# 50%                        10.000000                    431.000000
# 75%                        25.000000                    545.000000
# max                       430.000000                   7665.000000
#
#        aantal_personen_met_uitkering_onder_aowlft
# count                                21306.000000
# mean                                    59.640008
# std                                     79.993264
# min                                      5.000000
# 25%                                     10.000000
# 50%                                     30.000000
# 75%                                     75.000000
# max                                   1670.000000
#
# [8 rows x 22 columns]

# %% [markdown]
# #### Findings
# - population seems to make sense: 71,098 (500m resolution cells) * ~250 (mean) = 17,774,500, which is similar to the total population of NL, having excluded all null cells from the original dataset
# - aantal_inwoners: highly right-skewed (= much more counts in the lower range)
# - over 75% of the cells have around 185 people. => high-density areas are rare and extreme = compact urban centers, sparsed rural areas

# %%
# save cbs_filtered to a .csv and a .gpkg
cbs_filtered.to_file("../data/cbs/cleaned/cbs_filtered.gpkg", driver="GPKG")
cbs_filtered.to_csv("../data/cbs/cleaned/cbs_filtered.csv", index=False)

# %%
cbs_filtered.columns.tolist()
# Out:
# ['crs28992res500m',
#  'aantal_inwoners',
#  'aantal_mannen',
#  'aantal_vrouwen',
#  'aantal_inwoners_0_tot_15_jaar',
#  'aantal_inwoners_15_tot_25_jaar',
#  'aantal_inwoners_25_tot_45_jaar',
#  'aantal_inwoners_45_tot_65_jaar',
#  'aantal_inwoners_65_jaar_en_ouder',
#  'aantal_part_huishoudens',
#  'aantal_eenpersoonshuishoudens',
#  'aantal_meerpersoonshuishoudens_zonder_kind',
#  'aantal_eenouderhuishoudens',
#  'aantal_tweeouderhuishoudens',
#  'gemiddelde_huishoudensgrootte',
#  'aantal_woningen',
#  'aantal_meergezins_woningen',
#  'percentage_koopwoningen',
#  'percentage_huurwoningen',
#  'aantal_huurwoningen_in_bezit_woningcorporaties',
#  'aantal_niet_bewoonde_woningen',
#  'gemiddelde_woz_waarde_woning',
#  'aantal_personen_met_uitkering_onder_aowlft',
#  'geometry']

# %% [markdown]
# ### Check HH_500m_grid_2023.csv

# %%
# load HH_500m_grid_2023.csv
hh_500m_grid_2023 = pd.read_csv("../data/cbs/original/HH_500m_grid_2023.csv")
hh_500m_grid_2023.describe()
# hh_500m_grid_2023.shape

# copy and save this file to a new file
hh_500m_grid_2023.to_csv("../data/cbs/cleaned/HH_2023.csv", index=False)

# %%
# use the copied data to keep the original
hh_500m = pd.read_csv("../data/cbs/cleaned/HH_2023.csv")

# change column names 
hh_500m.rename(columns = {"VRLVIERKANT500M": "cell_id"}, inplace=True)
cbs_filtered.rename(columns = {"crs28992res500m": "cell_id"}, inplace=True)

# save them with the changed column names
hh_500m.to_csv("../data/cbs/cleaned/HH_2023.csv", index=False)
cbs_filtered.to_csv("../data/cbs/cleaned/cbs_filtered.csv", index=False)

# %%
# from cell_id columns from each csv, would like to find how many overlapping values there are
overlap = set(hh_500m['cell_id'].dropna()) & set(cbs_filtered['cell_id'].dropna())
len(overlap)
print(f"Overlapping cell_id values: {len(overlap)/hh_500m.shape[0]*100} %")
print(f"cell_id numbers in HH_2023.csv: {len(set(hh_500m['cell_id'].dropna()))}")
print(f"cell_id numbers in cbs_filtered.csv: {len(set(cbs_filtered['cell_id'].dropna()))}")

# find the cell_id numbers that are only in HH_2023.csv
only_hh_500m = set(hh_500m['cell_id'].dropna()) - set(cbs_filtered['cell_id'].dropna())
len(only_hh_500m)
# Out:
# Overlapping cell_id values: 93.71090989104778 %
# cell_id numbers in HH_2023.csv: 74986
# cell_id numbers in cbs_filtered.csv: 71098
# 4715

# %%
# change column names in cbs_filtered
cbs_filtered.rename(columns = {
    "crs28992res500m": "cell_id",
'aantal_inwoners' : "residents",
 'aantal_mannen' : "men",
 'aantal_vrouwen': "women",
 'aantal_inwoners_0_tot_15_jaar': "ppl_0_to_15",
 'aantal_inwoners_15_tot_25_jaar': "ppl_15_to_25",
 'aantal_inwoners_25_tot_45_jaar': "ppl_25_to_45",
 'aantal_inwoners_45_tot_65_jaar': "ppl_45_to_65",
 'aantal_inwoners_65_jaar_en_ouder': "ppl_65_and_older",
 'aantal_part_huishoudens': "households",
 'aantal_eenpersoonshuishoudens': "single_hh",
 'aantal_meerpersoonshuishoudens_zonder_kind': "hh_without_children",
 'aantal_eenouderhuishoudens': "single_parent_hh",
 'aantal_tweeouderhuishoudens': "two_parent_hh",
 'gemiddelde_huishoudensgrootte': "avg_hh_size",
 'aantal_woningen': "housing",
 'aantal_meergezins_woningen': "multi_family_units",
 'percentage_koopwoningen': "percentage_of_owner_occupied_units",
 'percentage_huurwoningen': "percentage_of_rental_units",
 'aantal_huurwoningen_in_bezit_woningcorporaties': "rental_owned_by_housing_corporations",
 'aantal_niet_bewoonde_woningen': "unoccupied_housing",
 'gemiddelde_woz_waarde_woning': "avg_property_value",
 'aantal_personen_met_uitkering_onder_aowlft': "people_with_disability_support",
    }, inplace=True)

# delete the people_with_disability_support column
cbs_filtered = cbs_filtered.drop(columns=["people_with_disability_support"])
cbs_filtered.columns
cbs_filtered.head()
# Out:
#       cell_id  residents    men  women  ppl_0_to_15  ppl_15_to_25  \
# 0  E2050N6110        5.0    NaN    NaN          NaN           NaN
# 1  E2060N6110       15.0   10.0    5.0          NaN           NaN
# 2  E2055N6105       30.0   10.0   15.0          NaN           NaN
# 3  E2060N6105      160.0   85.0   75.0          5.0          20.0
# 4  E2065N6105      365.0  190.0  175.0         40.0          35.0
#
#    ppl_25_to_45  ppl_45_to_65  ppl_65_and_older  households  ...  \
# 0           NaN           NaN               NaN         NaN  ...
# 1           NaN           NaN               5.0        10.0  ...
# 2           NaN           5.0              15.0        15.0  ...
# 3          40.0          40.0              55.0       110.0  ...
# 4          85.0         120.0              90.0       205.0  ...
#
#    two_parent_hh  avg_hh_size  housing  multi_family_units  \
# 0            NaN          NaN      NaN                 NaN
# 1            NaN          1.4      5.0                 NaN
# 2            NaN          1.8     20.0                 NaN
# 3           10.0          1.5    145.0                70.0
# 4           30.0          1.8    225.0                45.0
#
#    percentage_of_owner_occupied_units  percentage_of_rental_units  \
# 0                                 NaN                         NaN
# 1                                 NaN                         NaN
# 2                                70.0                        30.0
# 3                                50.0                        50.0
# 4                                50.0                        50.0
#
#    rental_owned_by_housing_corporations  unoccupied_housing  \
# 0                                   NaN                 NaN
# 1                                   NaN                 NaN
# 2                                   NaN                 5.0
# 3                                   5.0                65.0
# 4                                  95.0                30.0
#
#    avg_property_value                                           geometry
# 0                 NaN  MULTIPOLYGON (((205000 611500, 205500 611500, ...
# 1               741.0  MULTIPOLYGON (((206000 611500, 206500 611500, ...
# 2               677.0  MULTIPOLYGON (((205500 611000, 206000 611000, ...
# 3               400.0  MULTIPOLYGON (((206000 611000, 206500 611000, ...
# 4               349.0  MULTIPOLYGON (((206500 611000, 207000 611000, ...
#
# [5 rows x 23 columns]

# %%
# number of rows that have residents = 5
cbs_filtered[cbs_filtered['residents'] == 5]
len(cbs_filtered[cbs_filtered['residents'] == 5])
# Out:
# 10231

# %%
# save the filtered data again to csv and gpkg
cbs_filtered.to_csv("../data/cbs/cleaned/cbs_filtered.csv", index=False)
cbs_filtered.to_file("../data/cbs/cleaned/cbs_filtered.gpkg", driver="GPKG")

# %%
# get descriptive stats of cbs_filtered
cbs_filtered.describe()
# Out:
#           residents           men         women   ppl_0_to_15  ppl_15_to_25  \
# count  71098.000000  57793.000000  55775.000000  33798.000000  32722.000000
# mean     249.841346    151.925060    159.390856     78.901562     64.969592
# std      517.417027    276.420832    287.044526    105.618888    100.042157
# min        5.000000      5.000000      5.000000      5.000000      5.000000
# 25%       10.000000     10.000000     10.000000     10.000000     10.000000
# 50%       25.000000     20.000000     25.000000     30.000000     25.000000
# 75%      185.000000    160.000000    175.000000    115.000000     85.000000
# max     7290.000000   3560.000000   3730.000000   1215.000000   1915.000000
#
#        ppl_25_to_45  ppl_45_to_65  ppl_65_and_older    households  \
# count  36885.000000  47996.000000      38888.000000  50857.000000
# mean     120.304053     98.099008         90.775175    161.004188
# std      208.103924    150.843439        124.299778    300.945399
# min        5.000000      5.000000          5.000000      5.000000
# 25%       10.000000     10.000000         10.000000     10.000000
# 50%       35.000000     25.000000         30.000000     25.000000
# 75%      155.000000    130.000000        135.000000    180.000000
# max     3565.000000   1715.000000       1180.000000   4880.000000
#
#           single_hh  ...  single_parent_hh  two_parent_hh   avg_hh_size  \
# count  28342.000000  ...      16959.000000   31873.000000  50857.000000
# mean     113.167561  ...         34.161507      61.447777      2.405331
# std      200.988674  ...         37.247342      72.070477      0.520143
# min        5.000000  ...          5.000000       5.000000      1.000000
# 25%       10.000000  ...         10.000000      10.000000      2.100000
# 50%       40.000000  ...         20.000000      30.000000      2.400000
# 75%      130.000000  ...         45.000000      90.000000      2.700000
# max     3230.000000  ...        420.000000     710.000000      6.300000
#
#             housing  multi_family_units  percentage_of_owner_occupied_units  \
# count  49987.000000        16094.000000                        35123.000000
# mean     160.838818          182.307071                           75.200011
# std      289.838016          334.772524                           21.704507
# min        5.000000            5.000000                            0.000000
# 25%       10.000000           15.000000                           60.000000
# 50%       25.000000           60.000000                           80.000000
# 75%      185.000000          190.000000                           90.000000
# max     4775.000000         4770.000000                          100.000000
#
#        percentage_of_rental_units  rental_owned_by_housing_corporations  \
# count                21537.000000                          16578.000000
# mean                    36.204207                            139.131982
# std                     21.732829                            186.455358
# min                      0.000000                              5.000000
# 25%                     20.000000                             25.000000
# 50%                     30.000000                             75.000000
# 75%                     50.000000                            175.000000
# max                    100.000000                           2175.000000
#
#        unoccupied_housing  avg_property_value
# count        13410.000000        47105.000000
# mean            22.359806          462.427322
# std             31.587263          210.061907
# min              5.000000           12.000000
# 25%              5.000000          335.000000
# 50%             10.000000          431.000000
# 75%             25.000000          545.000000
# max            430.000000         7665.000000
#
# [8 rows x 21 columns]
